# %% [markdown]
# 1.Confidence Intervals
#
# a. Build 99% Confidence Interval Using Sample Standard Deviation
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import warnings
warnings.filterwarnings("ignore")

# %%
data=[1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]

# %%
x_bar=np.mean(data) # first we are caluclating the sample means

# %%
x_bar
# Out:
# np.float64(1.2386666666666666)

# %%
sample_std=np.std(data,ddof=1) # setting the  sample standard deviations

# %%
sample_std
# Out:
# np.float64(0.19316412956959936)

# %%
n=len(data) #caluclating the length of data

# %%
n
# Out:
# 15

# %%
confidence_level=0.99 #confidence interval 99%

# %%
confidence_level
# Out:
# 0.99

# %%
alpha=1-confidence_level #setting significance levels

# %%
alpha
# Out:
# 0.010000000000000009

# %%
degrees=n-1 # degrres for n

# %%
t_dists=t.ppf(1-alpha/2,degrees) #caluclating t_distributions that is t value for ci 99%

# %%
t_dists
# Out:
# np.float64(2.976842734370834)

# %%
t1=(t_dists)*(sample_std/np.sqrt(n)) #caluclating confidence intervals

# %%
t1
# Out:
# np.float64(0.14846932822817596)

# %%
t2=(t_dists)*(sample_std/np.sqrt(n))

# %%
t2
# Out:
# np.float64(0.14846932822817596)

# %%
ci_lower=x_bar-t1 #caluclating lower confidence intervals

# %%
ci_lower
# Out:
# np.float64(1.0901973384384906)

# %%
ci_upper=x_bar+t2 #caluclating lower confidence intervals

# %%
ci_upper
# Out:
# np.float64(1.3871359948948425)

# %% [markdown]
# b. Build 99% Confidence Interval Using Known Population Standard Deviation
#
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
n=len(data)

# %%
n #caluclating the length of data
# Out:
# 15

# %%
x_bars=np.mean(data) # first we are caluclating the sample means

# %%
x_bars
# Out:
# np.float64(1.2386666666666666)

# %%
pop_std=0.2 # setting the  pop standard deviations

# %%
pop_std
# Out:
# 0.2

# %%
confidence_level=0.99 #confidence interval 99%

# %%
alpha=1-confidence_level  #setting significance levels

# %%
alpha
# Out:
# 0.010000000000000009

# %%
z_dists=norm.ppf(1-alpha) #caluclating z_distributions that is t value for ci 99%

# %%
z_dists
# Out:
# np.float64(2.3263478740408408)

# %%
z1=z_dists*(pop_std/np.sqrt(n)) #caluclating confidence intervals

# %%
z1
# Out:
# np.float64(0.12013208764860274)

# %%
ci_zlowers=x_bars-z1 #caluclating lower confidence intervals

# %%
ci_zlowers
# Out:
# np.float64(1.1185345790180639)

# %%
ci_zuppers=x_bar+z1  #caluclating lower confidence intervals

# %%
ci_zuppers
# Out:
# np.float64(1.3587987543152693)

# %% [markdown]
# Hypothesis Testing

# %% [markdown]
# Background:
#
# Bombay hospitality Ltd. operates a franchise model for producing exotic Norwegian dinners throughout New England. The operating cost for a franchise in a week (W) is given by the equation W = $1,000 + $5X, where X represents the number of units produced in a week. Recent feedback from restaurant owners suggests that this cost model may no longer be accurate, as their observed weekly operating costs are higher.
#
# Objective:
#
# To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.
#
# Data Provided:
#
# ● The theoretical weekly operating cost model: W = $1,000 + $5X
#
# ● Sample of 25 restaurants with a mean weekly cost of Rs. 3,050
#
# ● Number of units produced in a week (X) follows a normal distribution with a mean (μ) of 600 units and a standard deviation (σ) of 25 units

# %% [markdown]
# 1. State the Hypotheses statements:

# %% [markdown]
# * Null hypothesis(H0) states that:
# there will be no increase in the weakly operating costs
# operating_costs=4000
#
#
# * Alternate hypothesis(H1) states that:
# there will be  increase in the weakly operating costs
# operating_costs>4000

# %% [markdown]
# 2. Calculate the Test Statistics:

# %%
x_bar=3050 #sample mean

# %%
mean=1000+5*(600) #population mean

# %%
mean
# Out:
# 4000

# %%
std_devs=5*25 #standard deviations

# %%
std_devs
# Out:
# 125

# %%
n=25

# %%
z_means=(x_bar-mean) #zmean

# %%
z_means
# Out:
# -950

# %%
std_errorrs=(std_devs/np.sqrt(n))  #standard errors

# %%
std_errorrs
# Out:
# np.float64(25.0)

# %%
z_statistics=z_means/std_errorrs #z_statistics

# %%
z_statistics
# Out:
# np.float64(-38.0)

# %% [markdown]
# 3. Determine the Probability and compare

# %%
alpha=0.05 #parameters

# %%
z_critics=norm.ppf(1-alpha) #critical values

# %%
print(f"critical value for alpha for one tailed test is :\n {z_critics}")
# Out:
# critical value for alpha for one tailed test is :
#  1.6448536269514722

# %% [markdown]
# 4. Make a Decision:

# %%
if z_statistics>z_critics:
    print(f"reject the null hypothesis since {z_statistics} is less than {z_critics}")
else:
    print(f"fails to reject null hypothesis since {z_critics} is greater than {z_statistics}")
# Out:
# fails to reject null hypothesis since 1.6448536269514722 is greater than -38.0

# %% [markdown]
#  5. Conclusion:

# %%
if z_statistics>z_critics:
    print("there is strong evidence to support the restaurant owners claim that the weekly operating costs are higher than the model suggests")
else:
    print(" there  no is strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests\n In fact, the observed weekly costs are significantly lower than predicted by the cost model.")
# Out:
#  there  no is strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests
#  In fact, the observed weekly costs are significantly lower than predicted by the cost model.
